# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
df= pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/indek IPM PMI.csv")
df.head(5)
# Out:
#    tahun  pct_tdk_cukup_pangan            prov  persen_anak_dengan_akte_lahir  \
# 0   2021                  6.90            ACEH                          94.52
# 1   2021                  6.33  SUMATERA UTARA                          83.02
# 2   2021                  6.02  SUMATERA BARAT                          91.38
# 3   2021                 10.61            RIAU                          84.25
# 4   2021                  9.25           JAMBI                          93.37
#
#    kepadatan_penduduk  persen_penduduk_trampil_tik  \
# 0                  92                        60.21
# 1                 205                        67.41
# 2                 133                        68.00
# 3                  75                        70.69
# 4                  72                        64.47
#
#    proporsi_hidup_dibawah_50_persen_median_pendapatan
# 0                                               9.98
# 1                                               5.87
# ...

# %%
#Hapus colom provinsi
df.drop("prov",axis=1)
# Out:
#      tahun  pct_tdk_cukup_pangan  persen_anak_dengan_akte_lahir  \
# 0     2021                  6.90                          94.52
# 1     2021                  6.33                          83.02
# 2     2021                  6.02                          91.38
# 3     2021                 10.61                          84.25
# 4     2021                  9.25                          93.37
# ..     ...                   ...                            ...
# 100   2019                 34.12                          78.66
# 101   2019                 35.81                          79.20
# 102   2019                 19.22                          75.05
# 103   2019                 38.21                          45.88
# 104   2019                  7.63                          86.01
#
#      kepadatan_penduduk  persen_penduduk_trampil_tik  \
# 0                    92                        60.21
# 1                   205                        67.41
# ...

# %%
df['persen_anak_dengan_akte_lahir'] = df['persen_anak_dengan_akte_lahir'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tahun                                               105 non-null    int64
#  1   pct_tdk_cukup_pangan                                105 non-null    object
#  2   prov                                                105 non-null    object
#  3   persen_anak_dengan_akte_lahir                       105 non-null    string
#  4   kepadatan_penduduk                                  105 non-null    int64
#  5   persen_penduduk_trampil_tik                         105 non-null    float64
#  6   proporsi_hidup_dibawah_50_persen_median_pendapatan  105 non-null    float64
# dtypes: float64(2), int64(2), object(2), string(1)
# memory usage: 5.9+ KB

# %%
df.loc[(df['pct_tdk_cukup_pangan'] < 60), 'pct_tdk_cukup_pangan'] = "Sangat Rendah"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df.loc[(df['pct_tdk_cukup_pangan'] < 60), 'pct_tdk_cukup_pangan'] = "Sangat Rendah"
#       2 df.loc[(60 < df['pct_tdk_cukup_pangan'] < 70 ), 'pct_tdk_cukup_pangan'] = "Sedang"
#       3 df.loc[(70 < df['pct_tdk_cukup_pangan'] < 80 ), 'pct_tdk_cukup_pangan'] = "Tinggi"
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# ...

# %%
df.head(50)
# Out:
#     tahun pct_tdk_cukup_pangan                  prov  \
# 0    2021        Sangat Rendah                  ACEH
# 1    2021        Sangat Rendah        SUMATERA UTARA
# 2    2021        Sangat Rendah        SUMATERA BARAT
# 3    2021        Sangat Rendah                  RIAU
# 4    2021        Sangat Rendah                 JAMBI
# 5    2021        Sangat Rendah      SUMATERA SELATAN
# 6    2021        Sangat Rendah              BENGKULU
# 7    2021        Sangat Rendah               LAMPUNG
# 8    2021        Sangat Rendah  KEP. BANGKA BELITUNG
# 9    2021        Sangat Rendah             KEP. RIAU
# 10   2021        Sangat Rendah           DKI JAKARTA
# 11   2021        Sangat Rendah            JAWA BARAT
# 12   2021        Sangat Rendah           JAWA TENGAH
# 13   2021        Sangat Rendah         DI YOGYAKARTA
# 14   2021        Sangat Rendah            JAWA TIMUR
# 15   2021        Sangat Rendah                BANTEN
# 16   2021        Sangat Rendah                  BALI
# ...

# %%
df.loc[(df['persen_anak_dengan_akte_lahir'] < 60), 'persen_anak_dengan_akte_lahir'] = "Sangat Rendah"
df.loc[(60 < df['persen_anak_dengan_akte_lahir'] < 70 ), 'persen_anak_dengan_akte_lahir'] = "Sedang"
df.loc[(70 < df['persen_anak_dengan_akte_lahir'] < 80 ), 'persen_anak_dengan_akte_lahir'] = "Tinggi"
df.loc[(80 < df['persen_anak_dengan_akte_lahir'] ), 'persen_anak_dengan_akte_lahir'] = "Sangat Tinggi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df.loc[(df['persen_anak_dengan_akte_lahir'] < 60), 'persen_anak_dengan_akte_lahir'] = "Sangat Rendah"
#       2 df.loc[(60 < df['persen_anak_dengan_akte_lahir'] < 70 ), 'persen_anak_dengan_akte_lahir'] = "Sedang"
#       3 df.loc[(70 < df['persen_anak_dengan_akte_lahir'] < 80 ), 'persen_anak_dengan_akte_lahir'] = "Tinggi"
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ...
