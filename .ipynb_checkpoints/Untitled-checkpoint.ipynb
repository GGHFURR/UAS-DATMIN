# %% [markdown]
# # UAS Data Mining And Warehouse
#
# Muhammad Fadlan Ghafur
# 2106923

# %% [markdown]
# Disini saya menggunakan 5 dataset dimana saya mengambil
# - Ketidak cukupan pangan
# - Kepadatan Penduduk
# - Persen Anak akte kelahiran
# - Proporsi Median 50% dibawah pendapatan
# - persen penduduk terampil
#
# dimana untuk mengejar IPM (indeks pembangunan manusia) dibutuhkan beberapa
# karakteristik yaitu
# 1. Umur panjang dan hidup sehat
# 2. Pengetahuan
# 3. standar hidup layak
#
# nah, untuk masing masing dataset yang saya ambil itu memiliki keterkaitan dengan
# 3 karakter tersebut.
#
# * ketidak cukupan pangan mengisi pada hidup sehat.
# * kepadatan penduduk untuk mengukur standar hidup layak
# * anak akte kelahiran untuk menghitung pertumbuhan penduduk yang berkaitan dengan
# umur panjang dan hidup sehat
# * lalu proporsi median 50% dibawah pendapatan untuk menyatakan standar ekonomi warga
# * dan terakhir penduduk terampil untuk pengetahuan.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from datetime import datetime, date

# %%
#membaca dataset pangan
df_pangan = pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/ketidak_cukupan_pangan_prov.csv")
df_pangan.head(5)
# Out:
#    tahun  pct_tdk_cukup_pangan            prov
# 0   2021                  6.90            ACEH
# 1   2021                  6.33  SUMATERA UTARA
# 2   2021                  6.02  SUMATERA BARAT
# 3   2021                 10.61            RIAU
# 4   2021                  9.25           JAMBI

# %%
df_pangan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tahun                 175 non-null    int64
#  1   pct_tdk_cukup_pangan  175 non-null    float64
#  2   prov                  175 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.2+ KB

# %%
#membaca dataset kepadatan penduduk
df_pend = pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/kepadatan_penduduk.csv")
df_pend.head(5)
# Out:
#              prov  tahun kepadatan_penduduk
# 0            ACEH   2021                 92
# 1  SUMATERA UTARA   2021                205
# 2  SUMATERA BARAT   2021                133
# 3            RIAU   2021                 75
# 4           JAMBI   2021                 72

# %%
df_pend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   prov                280 non-null    object
#  1   tahun               280 non-null    int64
#  2   kepadatan_penduduk  280 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 6.7+ KB

# %%
#membaca dataset anak dengan akte kelahiran
df_akt = pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/persen_anak_dengan_akte_lahir.csv")
df_akt.head(5)
# Out:
#    tahun  persen_anak_dengan_akte_lahir            prov
# 0   2021                          94.52            ACEH
# 1   2021                          83.02  SUMATERA UTARA
# 2   2021                          91.38  SUMATERA BARAT
# 3   2021                          84.25            RIAU
# 4   2021                          93.37           JAMBI

# %%
df_akt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tahun                          245 non-null    int64
#  1   persen_anak_dengan_akte_lahir  245 non-null    float64
#  2   prov                           245 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.9+ KB

# %%
#membaca dataset proporsi hidup
df_propo = pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/proporsi_hidup_dibawah_50_persen_median_pendapatan.csv")
df_propo.head(5)
# Out:
#    tahun  proporsi_hidup_dibawah_50_persen_median_pendapatan            prov
# 0   2021                                               9.98             ACEH
# 1   2021                                               5.87   SUMATERA UTARA
# 2   2021                                               2.47   SUMATERA BARAT
# 3   2021                                               2.52             RIAU
# 4   2021                                               5.91            JAMBI

# %%
df_propo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 3 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tahun                                               140 non-null    int64
#  1   proporsi_hidup_dibawah_50_persen_median_pendapatan  140 non-null    float64
#  2   prov                                                140 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.4+ KB

# %%
#membaca dataset penduduk terampil
df_terampil = pd.read_csv("D:/Kuliah/Semester 3/UAS datmin/persen_penduduk_trampil_tik.csv")
df_terampil.head(5)
# Out:
#    tahun  persen_penduduk_trampil_tik            prov
# 0   2021                        60.21            ACEH
# 1   2021                        67.41  SUMATERA UTARA
# 2   2021                        68.00  SUMATERA BARAT
# 3   2021                        70.69            RIAU
# 4   2021                        64.47           JAMBI

# %%
df_terampil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   tahun                        245 non-null    int64
#  1   persen_penduduk_trampil_tik  245 non-null    float64
#  2   prov                         245 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.9+ KB

# %%
#memgabungkan dataset pangan dan akte
df = pd.merge(df_pangan, df_akt, how = 'inner')
df.head(1)
# Out:
#    tahun  pct_tdk_cukup_pangan  prov  persen_anak_dengan_akte_lahir
# 0   2021                   6.9  ACEH                          94.52

# %%
df.head(20)
# Out:
#     tahun  pct_tdk_cukup_pangan                  prov  \
# 0    2021                  6.90                  ACEH
# 1    2021                  6.33        SUMATERA UTARA
# 2    2021                  6.02        SUMATERA BARAT
# 3    2021                 10.61                  RIAU
# 4    2021                  9.25                 JAMBI
# 5    2021                  6.82      SUMATERA SELATAN
# 6    2021                  8.64              BENGKULU
# 7    2021                 10.25               LAMPUNG
# 8    2021                 11.05  KEP. BANGKA BELITUNG
# 9    2021                  7.71             KEP. RIAU
# 10   2021                  2.20           DKI JAKARTA
# 11   2021                  4.44            JAWA BARAT
# 12   2021                 12.34           JAWA TENGAH
# 13   2021                 10.18         DI YOGYAKARTA
# 14   2021                  9.14            JAWA TIMUR
# 15   2021                  2.80                BANTEN
# ...

# %%
#memgabungkan dataset sebelumnya dgn kepadatan penduduk
df = pd.merge(df, df_pend, how = 'inner')
df.head(1)
# Out:
#    tahun  pct_tdk_cukup_pangan  prov  persen_anak_dengan_akte_lahir  \
# 0   2021                   6.9  ACEH                          94.52
#
#   kepadatan_penduduk
# 0                 92

# %%
df.head(20)
# Out:
#     tahun  pct_tdk_cukup_pangan                  prov  \
# 0    2021                  6.90                  ACEH
# 1    2021                  6.33        SUMATERA UTARA
# 2    2021                  6.02        SUMATERA BARAT
# 3    2021                 10.61                  RIAU
# 4    2021                  9.25                 JAMBI
# 5    2021                  6.82      SUMATERA SELATAN
# 6    2021                  8.64              BENGKULU
# 7    2021                 10.25               LAMPUNG
# 8    2021                 11.05  KEP. BANGKA BELITUNG
# 9    2021                  7.71             KEP. RIAU
# 10   2021                  2.20           DKI JAKARTA
# 11   2021                  4.44            JAWA BARAT
# 12   2021                 12.34           JAWA TENGAH
# 13   2021                 10.18         DI YOGYAKARTA
# 14   2021                  9.14            JAWA TIMUR
# 15   2021                  2.80                BANTEN
# ...

# %%
#memgabungkan dataset sebelumnya dgn kepadatan penduduk terampil
df = pd.merge(df, df_terampil, how = 'inner')
df.head(1)
# Out:
#    tahun  pct_tdk_cukup_pangan  prov  persen_anak_dengan_akte_lahir  \
# 0   2021                   6.9  ACEH                          94.52
#
#   kepadatan_penduduk  persen_penduduk_trampil_tik
# 0                 92                        60.21

# %%
df.head(20)
# Out:
#     tahun  pct_tdk_cukup_pangan                  prov  \
# 0    2021                  6.90                  ACEH
# 1    2021                  6.33        SUMATERA UTARA
# 2    2021                  6.02        SUMATERA BARAT
# 3    2021                 10.61                  RIAU
# 4    2021                  9.25                 JAMBI
# 5    2021                  6.82      SUMATERA SELATAN
# 6    2021                  8.64              BENGKULU
# 7    2021                 10.25               LAMPUNG
# 8    2021                 11.05  KEP. BANGKA BELITUNG
# 9    2021                  7.71             KEP. RIAU
# 10   2021                  2.20           DKI JAKARTA
# 11   2021                  4.44            JAWA BARAT
# 12   2021                 12.34           JAWA TENGAH
# 13   2021                 10.18         DI YOGYAKARTA
# 14   2021                  9.14            JAWA TIMUR
# 15   2021                  2.80                BANTEN
# ...

# %%
#memgabungkan dataset sebelumnya dgn proporsi hidup
df = pd.merge(df, df_propo, how = 'inner')
df.head(1)
# Out:
#    tahun  pct_tdk_cukup_pangan  prov  persen_anak_dengan_akte_lahir  \
# 0   2021                   6.9  ACEH                          94.52
#
#   kepadatan_penduduk  persen_penduduk_trampil_tik  \
# 0                 92                        60.21
#
#    proporsi_hidup_dibawah_50_persen_median_pendapatan
# 0                                               9.98

# %%
#mengecek hasil semua merge CSV yang di perlukan
df.head(20)
# Out:
#     tahun  pct_tdk_cukup_pangan                  prov  \
# 0    2021                  6.90                  ACEH
# 1    2021                  6.33        SUMATERA UTARA
# 2    2021                  6.02        SUMATERA BARAT
# 3    2021                 10.61                  RIAU
# 4    2021                  9.25                 JAMBI
# 5    2021                  6.82      SUMATERA SELATAN
# 6    2021                  8.64              BENGKULU
# 7    2021                 10.25               LAMPUNG
# 8    2021                 11.05  KEP. BANGKA BELITUNG
# 9    2021                  7.71             KEP. RIAU
# 10   2021                  2.20           DKI JAKARTA
# 11   2021                  4.44            JAWA BARAT
# 12   2021                 12.34           JAWA TENGAH
# 13   2021                 10.18         DI YOGYAKARTA
# 14   2021                  9.14            JAWA TIMUR
# 15   2021                  2.80                BANTEN
# ...

# %%
# mengecek bentuk data dari dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tahun                                               105 non-null    int64
#  1   pct_tdk_cukup_pangan                                105 non-null    float64
#  2   prov                                                105 non-null    object
#  3   persen_anak_dengan_akte_lahir                       105 non-null    float64
#  4   kepadatan_penduduk                                  105 non-null    object
#  5   persen_penduduk_trampil_tik                         105 non-null    float64
#  6   proporsi_hidup_dibawah_50_persen_median_pendapatan  105 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 6.6+ KB

# %%
#mengecek apakah ada yang null
df.isna().sum()
# Out:
# tahun                                                 0
# pct_tdk_cukup_pangan                                  0
# prov                                                  0
# persen_anak_dengan_akte_lahir                         0
# kepadatan_penduduk                                    0
# persen_penduduk_trampil_tik                           0
# proporsi_hidup_dibawah_50_persen_median_pendapatan    0
# dtype: int64

# %%
df.drop("prov",axis=1)
# Out:
#      tahun  pct_tdk_cukup_pangan  persen_anak_dengan_akte_lahir  \
# 0     2021                  6.90                          94.52
# 1     2021                  6.33                          83.02
# 2     2021                  6.02                          91.38
# 3     2021                 10.61                          84.25
# 4     2021                  9.25                          93.37
# ..     ...                   ...                            ...
# 100   2019                 34.12                          78.66
# 101   2019                 35.81                          79.20
# 102   2019                 19.22                          75.05
# 103   2019                 38.21                          45.88
# 104   2019                  7.63                          86.01
#
#     kepadatan_penduduk  persen_penduduk_trampil_tik  \
# 0                   92                        60.21
# 1                  205                        67.41
# ...

# %%
results = pd.crosstab(df.persen_anak_dengan_akte_lahir,df.pct_tdk_cukup_pangan,df.kepadatan_penduduk,df.persen_penduduk_trampil_tik,df.proporsi_hidup_dibawah_50_persen_median_pendapatan)
results.columns = ['akte','pangan','padat','terampil','proporsi','IPM']
results['IPM'] = results['akte'] + results['pangan']  + results['padat']  + results['terampil'] + results['proporsi']  
results['IPM'] = results['IPM']/5
# result_merges = pd.DataFrame()
# result_merges['return_state'] = results['return_state']
# result_merges['not_return_state'] = results['not_return_state']
# result_merges.head(1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='kepadatan_penduduk'>
